# %% [markdown]
# # AIRPLANE CRASHES CLUSTRING

# %% [markdown]
# <img align="top"  width="900" height="300" src="https://images.unsplash.com/photo-1515526996020-12f6c0a386d0?ixid=MnwxMjA3fDB8MHxzZWFyY2h8MXx8cGxhbmUlMjBjcmFzaHxlbnwwfHwwfHw%3D&ixlib=rb-1.2.1&w=1000&q=80">

# %% [markdown]
# ## About this file
# __This dataset includes:__
#
#     *All civil and commercial aviation accidents of scheduled and non-scheduled passenger airliners worldwide, which              resulted in a fatality (including all U.S. Part 121 and Part 135 fatal accidents)
#     *All cargo, positioning, ferry and test flight fatal accidents.
#     *All military transport accidents with 10 or more fatalities.
#     *All commercial and military helicopter accidents with greater than 10 fatalities.
#     *All civil and military airship accidents involving fatalities.
#     *Aviation accidents involving the death of famous people.
#     *Aviation accidents or incidents of noteworthy interest.

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %% [markdown]
# ## LOADING DATASET

# %%
data = pd.read_csv("Airplane_Crashes_and_Fatalities_Since_1908.csv")
data.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %% [markdown]
# ## DATA INSIGHTS

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5248 entries, 0 to 5267
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5248 non-null   object
#  1   Time          3046 non-null   object
#  2   Location      5248 non-null   object
#  3   Operator      5231 non-null   object
#  4   Flight #      1067 non-null   object
#  5   Route         3554 non-null   object
#  6   Type          5221 non-null   object
#  7   Registration  4917 non-null   object
#  8   cn/In         4028 non-null   object
#  9   Aboard        5248 non-null   float64
#  10  Fatalities    5248 non-null   float64
#  11  Ground        5248 non-null   float64
#  12  Summary       4865 non-null   object
#  13  year          5248 non-null   int64
#  14  Survived      5248 non-null   float64
#  15  Country       5248 non-null   object
#  16  month         5248 non-null   int64
#  17  crashes       95 non-null     float64
# ...

# %%
data.describe()
# Out:
#             Aboard   Fatalities       Ground
# count  5246.000000  5256.000000  5246.000000
# mean     27.554518    20.068303     1.608845
# std      43.076711    33.199952    53.987827
# min       0.000000     0.000000     0.000000
# 25%       5.000000     3.000000     0.000000
# 50%      13.000000     9.000000     0.000000
# 75%      30.000000    23.000000     0.000000
# max     644.000000   583.000000  2750.000000

# %% [markdown]
# ## SHAPE OF THE DATA

# %%
data.shape
# Out:
# (5268, 13)

# %% [markdown]
# ## VALUE COUNTS PER COLUMNS

# %%
data["Location"].value_counts()
# Out:
# Sao Paulo, Brazil                      15
# Moscow, Russia                         15
# Rio de Janeiro, Brazil                 14
# Bogota, Colombia                       13
# Manila, Philippines                    13
#                                        ..
# Malemba Nkulu, DR Congo                 1
# Malanje, Angola                         1
# Guadalcanal Island, Solomon Islands     1
# Anchor Point, Alaska                    1
# Mount Cook, New Zealand                 1
# Name: Location, Length: 4303, dtype: int64

# %%
data["Route"].value_counts()
# Out:
# Training                           81
# Sightseeing                        29
# Test flight                        17
# Test                                6
# Sao Paulo - Rio de Janeiro          5
#                                    ..
# Altukaki - Rarotonga                1
# Halifax - Sidney NS                 1
# Honolulu - Pago Pago - Auckland     1
# Chandigarh - Leh                    1
# Gods Narrows - Shamattawa           1
# Name: Route, Length: 3244, dtype: int64

# %%
data["Flight #"].value_counts()
# Out:
# -       67
# 1       10
# 4        7
# 101      6
# 6        6
#         ..
# 20       1
# 725      1
# 4272     1
# 561      1
# 5        1
# Name: Flight #, Length: 724, dtype: int64

# %%
data["Type"].value_counts()
# Out:
# Douglas DC-3                                334
# de Havilland Canada DHC-6 Twin Otter 300     81
# Douglas C-47A                                74
# Douglas C-47                                 62
# Douglas DC-4                                 40
#                                            ...
# Boeing B-757-225                              1
# Curtiss C-46, C-47, DC-3                      1
# Boeing B-727-230                              1
# Cessna 210L                                   1
# MBB HFB-320 Hansa Jet                         1
# Name: Type, Length: 2446, dtype: int64

# %%
data['Registration'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 5263     A-1325
# 5264     9Q-CSA
# 5265     F-GZCP
# 5266    C-FJJR
# 5267        NaN
# Name: Registration, Length: 5268, dtype: object>

# %%
data['Aboard'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         2.0
# 1         5.0
# 2         1.0
# 3        20.0
# 4        30.0
#         ...
# 5263    112.0
# 5264      4.0
# 5265    228.0
# 5266      1.0
# 5267     13.0
# Name: Aboard, Length: 5268, dtype: float64>

# %%
data['Summary'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       During a demonstration flight, a U.S. Army fly...
# 1       First U.S. dirigible Akron exploded just offsh...
# 2       The first fatal airplane accident in Canada oc...
# 3       The airship flew into a thunderstorm and encou...
# 4       Hydrogen gas which was being vented was sucked...
#                               ...
# 5263    While on approach, the military transport cras...
# 5264    The cargo plane crashed while on approach to I...
# 5265    The Airbus went missing over the AtlantiOcean ...
# 5266    The air ambulance crashed into hills while att...
# 5267    The military transport went missing while en r...
# Name: Summary, Length: 5268, dtype: object>

# %%
data.isnull().sum()
# Out:
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
data.isnull().sum()/data.shape[0]
# Out:
# Date            0.000000
# Time            0.421222
# Location        0.003797
# Operator        0.003417
# Flight #        0.797077
# Route           0.323842
# Type            0.005125
# Registration    0.063591
# cn/In           0.233106
# Aboard          0.004176
# Fatalities      0.002278
# Ground          0.004176
# Summary         0.074032
# dtype: float64

# %% [markdown]
# ## FEATURE ENGINEERING

# %%
data['Fatalities'].fillna(0, inplace = True)
data['Aboard'].fillna(0, inplace = True)
data['Ground'].fillna(0, inplace = True)

# %% [markdown]
# ### COUNVERTING DATE COLUMN INTO SEPERATE COLUMNS

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['Date'] = data['Date'].dt.strftime("%d/%m/%Y")
data['Date'].head()
# Out:
# 0    17/09/1908
# 1    12/07/1912
# 2    06/08/1913
# 3    09/09/1913
# 4    17/10/1913
# Name: Date, dtype: object

# %%
data["year"] = pd.DatetimeIndex(data["Date"]).year
data.head()
# Out:
#          Date   Time                            Location  \
# 0  17/09/1908  17:18                 Fort Myer, Virginia
# 1  12/07/1912  06:30             AtlantiCity, New Jersey
# 2  06/08/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  17/10/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %%
data["Ground"].value_counts()
# Out:
# 0.0       5049
# 1.0         53
# 2.0         27
# 3.0         21
# 4.0         15
# 8.0         10
# 5.0         10
# 7.0          8
# 11.0         6
# 6.0          6
# 22.0         5
# 13.0         4
# 20.0         3
# 10.0         3
# 24.0         3
# 44.0         3
# 14.0         2
# 12.0         2
# 70.0         2
# 47.0         2
# 2750.0       2
# 30.0         2
# 19.0         2
# 52.0         2
# 31.0         1
# 36.0         1
# 75.0         1
# 225.0        1
# 23.0         1
# 18.0         1
# 58.0         1
# 87.0         1
# 107.0        1
# 16.0         1
# 35.0         1
# 17.0         1
# 37.0         1
# 49.0         1
# 113.0        1
# 63.0         1
# 40.0         1
# 50.0         1
# 125.0        1
# 33.0         1
# 45.0         1
# 15.0         1
# 85.0         1
# 32.0         1
# 9.0          1
# 54.0         1
# Name: Ground, dtype: int64

# %%
data['cn/In'].value_counts()
# Out:
# 178          6
# 229          5
# 19           5
# 213          5
# 125          5
#             ..
# 43748/314    1
# 402C-0638    1
# 12541        1
# 10284        1
# 5            1
# Name: cn/In, Length: 3707, dtype: int64

# %% [markdown]
# ## ADDING SURVUVED  COLUMN

# %%
data["Survived"] = data["Aboard"] - data["Fatalities"]
data.Survived.head(10)
# Out:
# 0     1.0
# 1     0.0
# 2     0.0
# 3     6.0
# 4     0.0
# 5    20.0
# 6     0.0
# 7     0.0
# 8     0.0
# 9     0.0
# Name: Survived, dtype: float64

# %%
data["Survived"].isnull().sum()
# Out:
# 0

# %%
data.head()
# Out:
#          Date   Time                            Location  \
# 0  17/09/1908  17:18                 Fort Myer, Virginia
# 1  12/07/1912  06:30             AtlantiCity, New Jersey
# 2  06/08/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  17/10/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %% [markdown]
# # DATA VISULAIZATION

# %%
total_crashes_year = data[['year', 'Date']].groupby('year').count()
total_crashes_year = total_crashes_year.reset_index()
total_crashes_year.columns = ['Year', 'Crashes']

# %% [markdown]
# ## LINE PLOT B/T NO. OF YEAR AND CRASHES PER YEAR

# %%
plt.figure(figsize = (20,10))
sns.lineplot(x = 'Year', y = 'Crashes', data = total_crashes_year)
plt.title('Total Airplane Crashes per Year')
plt.xlabel('years')
plt.ylabel('number of crashes')
plt.show()

# %%
def split_country(x):
    a = x.split(",")[-1]
    return a.replace(" ","")

# %%
data["Location"].isnull().sum()
# Out:
# 20

# %%
data.dropna(inplace=True, subset=['Location'])

# %%
data["Location"].isnull().sum()
# Out:
# 0

# %%
data["Country"] = data["Location"].apply(split_country)

# %%
data.head()
# Out:
#          Date   Time                            Location  \
# 0  17/09/1908  17:18                 Fort Myer, Virginia
# 1  12/07/1912  06:30             AtlantiCity, New Jersey
# 2  06/08/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  17/10/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %%
data["Country"].value_counts()
# Out:
# Brazil                189
# Alaska                177
# Russia                175
# Colombia              149
# Canada                149
#                      ...
# SainteLuciaIsland       1
# Rhodesia(Zimbabwe)      1
# Russian                 1
# offBermuda              1
# Croatia                 1
# Name: Country, Length: 495, dtype: int64

# %%
data.groupby("Country")["Date"].count()
# Out:
# Country
# 110milesWestofIreland              1
# 325mileseastofWakeIsland           1
# AK                                 2
# Afghanistan                       32
# Afghanstan                         2
#                                   ..
# Zimbabwe                           2
# offAngola                          1
# offAustralia                       1
# offBermuda                         1
# offthePhilippineislandofElalat     1
# Name: Date, Length: 495, dtype: int64

# %%
x = "Alabama, Alaska, AmericanSamoa, Arizona, Arkansas, California, Colorado, Connecticut, Delaware, DistrictofColumbia, Florida, Georgia, Guam, Hawaii, Idaho, \
Illinois, Indiana, Iowa, Kansas, Kentucky, Louisiana, Maine, Maryland, Massachusetts, Michigan, Minnesota, Minor OutlyingIslands, Mississippi, Missouri, Montana, \
Nebraska, Nevada, NewHampshire, NewJersey, NewMexico, NewYork, NorthCarolina, NorthDakota, NorthernMarianaIslands, Ohio, Oklahoma, Oregon, Pennsylvania, PuertoRico,\
 Rhode Island, South Carolina, South Dakota, Tennessee, Texas, U.S.VirginIslands, Utah, Vermont, Virginia, Washington, West Virginia, Wisconsin, Wyoming"
x=x.split(", ")
x=pd.Series(x)

# %%
index = data["Country"].isin(x)
data.loc[index ,'Country'] = 'USA'
data.head()
# Out:
#          Date   Time                            Location  \
# 0  17/09/1908  17:18                 Fort Myer, Virginia
# 1  12/07/1912  06:30             AtlantiCity, New Jersey
# 2  06/08/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  17/10/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %%
data["Country"].value_counts()
# Out:
# USA           1367
# Brazil         189
# Russia         175
# Colombia       149
# Canada         149
#               ...
# Russian          1
# offBermuda       1
# Guernsey         1
# Virginia.        1
# Croatia          1
# Name: Country, Length: 446, dtype: int64

# %% [markdown]
# ## BAR_PLOT B/T COUNTRY AND CRASHES

# %%
By_country = data.groupby("Country")["Date"].count().head(50)
plt.figure(figsize = (20,10))
By_country.plot(kind = "bar")
plt.xlabel("Country")
plt.ylabel("crashes")
plt.show()

# %%
data["Survived"].value_counts()
# Out:
# 0.0      3513
# 1.0       285
# 2.0       190
# 3.0       115
# 4.0       112
#          ...
# 172.0       1
# 89.0        1
# 168.0       1
# 210.0       1
# 298.0       1
# Name: Survived, Length: 174, dtype: int64

# %% [markdown]
# ## JOINT_PLOT FOR CHECKING DENSITY OF THE COLUMN

# %%
plt.figure(figsize=(30,10))
sns.jointplot(x='Survived', y='year' , data=data , kind='kde',shade=True, height=5)
plt.show()

# %%
By_death =data.groupby("year")["Fatalities"].sum().head(20).sort_values(ascending = False)
#By_death = By_death.sort_values(["Fatalities"],ascending=True)

plt.figure(figsize=(40,20))
#sns.barplot(x="year", y="Fatalities",data = data)
By_death.plot(kind = "bar")
plt.show()

# %%
pcdeaths_year = data[['year', 'Fatalities']].groupby('year').sum()
pcdeaths_year.reset_index(inplace = True)
pcdeaths_year
# Out:
#     year  Fatalities
# 0   1908         1.0
# 1   1912         5.0
# 2   1913        45.0
# 3   1915        40.0
# 4   1916       108.0
# ..   ...         ...
# 93  2005      1291.0
# 94  2006      1136.0
# 95  2007       931.0
# 96  2008       820.0
# 97  2009       581.0
#
# [98 rows x 2 columns]

# %% [markdown]
# ## LINE_PLOT B/T YEAR AND FATALITITIES

# %%
plt.figure(figsize=(30,20))
sns.lineplot(x = 'year', y = 'Fatalities', data =pcdeaths_year )
plt.title('Total Number of Fatalities by Air Plane Crashes per Year')
plt.xlabel('Fatalities')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
ppl_aboard = data[["year", "Aboard"]].groupby("year").sum()
ppl_aboard.reset_index(inplace = True)
ppl_aboard
# Out:
#     year  Aboard
# 0   1908     2.0
# 1   1912     5.0
# 2   1913    51.0
# 3   1915    60.0
# 4   1916   109.0
# ..   ...     ...
# 93  2005  2146.0
# 94  2006  1413.0
# 95  2007  1364.0
# 96  2008  1463.0
# 97  2009   891.0
#
# [98 rows x 2 columns]

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = 'year', y = 'Fatalities', data =pcdeaths_year )
plt.title('Total Number of Aboard by Air Plane Crashes per Year')
plt.xlabel('Aboard')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
FCG_per_year = data[['year', 'Fatalities', 'Survived', 'Ground']].groupby("year").sum()
FCG_per_year.reset_index(inplace = True)
FCG_per_year
# Out:
#     year  Fatalities  Survived  Ground
# 0   1908         1.0       1.0     0.0
# 1   1912         5.0       0.0     0.0
# 2   1913        45.0       6.0     0.0
# 3   1915        40.0      20.0     0.0
# 4   1916       108.0       1.0     0.0
# ..   ...         ...       ...     ...
# 93  2005      1291.0     855.0    59.0
# 94  2006      1136.0     277.0     4.0
# 95  2007       931.0     433.0    57.0
# 96  2008       820.0     643.0    60.0
# 97  2009       581.0     310.0     3.0
#
# [98 rows x 4 columns]

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = 'year', y = 'Fatalities', data = FCG_per_year, color = 'green')
sns.lineplot(x = 'year', y = 'Survived', data = FCG_per_year, color = 'blue')
sns.lineplot(x = 'year', y = 'Ground', data = FCG_per_year, color = 'red')
plt.legend(['Fatalyties', 'Survival', 'Ground'])
plt.xlabel('Years')
plt.ylabel('Count')
plt.title('Fatalities vs Survived vs Killed on Ground per Year')
# Out:
# Text(0.5, 1.0, 'Fatalities vs Survived vs Killed on Ground per Year')

# %%
data.corr()
# Out:
#               Aboard  Fatalities    Ground      year  Survived
# Aboard      1.000000    0.756761  0.023281  0.157659  0.636864
# Fatalities  0.756761    1.000000  0.035188  0.110598 -0.022027
# Ground      0.023281    0.035188  1.000000  0.029223 -0.005894
# year        0.157659    0.110598  0.029223  1.000000  0.110683
# Survived    0.636864   -0.022027 -0.005894  0.110683  1.000000

# %%
plt.figure(figsize=(30,30))
corr = data.corr()
sns.heatmap(data=corr, square=True, annot=True, cbar=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data[data.corr()['year'].sort_values(ascending=False).index[:5]])
plt.show();

# %%
data["month"] = pd.DatetimeIndex(data["Date"]).month
data.head()
# Out:
#          Date   Time                            Location  \
# 0  17/09/1908  17:18                 Fort Myer, Virginia
# 1  12/07/1912  06:30             AtlantiCity, New Jersey
# 2  06/08/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  17/10/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %%
plt.scatter(data["Survived"], data["Ground"], data["Aboard"], data['Fatalities'])

# %%
By_month = data[["year","month"]].groupby("year").sum()
By_month.reset_index(inplace = True)
By_month
# Out:
#     year  month
# 0   1908      9
# 1   1912     12
# 2   1913     25
# 3   1915      8
# 4   1916     39
# ..   ...    ...
# 93  2005    286
# 94  2006    322
# 95  2007    333
# 96  2008    369
# 97  2009    121
#
# [98 rows x 2 columns]

# %%
plt.figure(figsize=(30,20))
sns.barplot(x = 'year', y = 'Fatalities', data =pcdeaths_year )
plt.title('Months by Air Plane Crashes per Year')
plt.xlabel('months')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
data["Operator"].value_counts()
# Out:
# Aeroflot                          179
# Military - U.S. Air Force         176
# Air France                         70
# Deutsche Lufthansa                 62
# United Air Lines                   44
#                                  ...
# Conesul Taxi Aéreo                  1
# COPA (Panama)                       1
# Military - Royal Airship Works      1
# Dominicana                          1
# MaRobertson Miller Airlines         1
# Name: Operator, Length: 2471, dtype: int64

# %%
data[["year","Operator"]].groupby("year").sum()
# Out:
#                                                Operator
# year
# 1908                               Military - U.S. Army
# 1912                               Military - U.S. Navy
# 1913  PrivateMilitary - German NavyMilitary - German...
# 1915       Military - German NavyMilitary - German Navy
# 1916  Military - German ArmyMilitary - German NavyMi...
# ...                                                 ...
# 2005  Military - Colombian governmentTura Air Enterp...
# 2006  Trigana Air ServiceEvolgaService AirMilitary -...
# 2007                                                NaN
# 2008  Military - Macedonian Air ForceTransavenServan...
# 2009  Petroleum Helicopters IncUS AirwaysAerotaxi Ma...
#
# [98 rows x 1 columns]

# %%
By_country = data.groupby("Country")["Date"].count()
By_country = By_country.reset_index()
By_country.sort_values(by = "Date", ascending = False)
# Out:
#                             Country  Date
# 404                             USA  1367
# 53                           Brazil   189
# 340                          Russia   175
# 83                         Colombia   149
# 69                           Canada   149
# ..                              ...   ...
# 202                        Louisana     1
# 201                          London     1
# 200                       Lithuania     1
# 197                         Lesotho     1
# 445  offthePhilippineislandofElalat     1
#
# [446 rows x 2 columns]

# %% [markdown]
# ## MODEL BUILDING USING K MEANS CLUSTER

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import adjusted_rand_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# ## FORMING DATA FOR FURTHER PREDICTION

# %% [markdown]
# #### In the 'Summary' column, we have NaN values as well, so we're going to create a new dataframe with the 'Summary' data and dropping all rows with NaN values.

# %%
Text_data = data["Summary"].dropna()
Text_data = pd.DataFrame(Text_data)
Text_data
# Out:
#                                                 Summary
# 0     During a demonstration flight, a U.S. Army fly...
# 1     First U.S. dirigible Akron exploded just offsh...
# 2     The first fatal airplane accident in Canada oc...
# 3     The airship flew into a thunderstorm and encou...
# 4     Hydrogen gas which was being vented was sucked...
# ...                                                 ...
# 5263  While on approach, the military transport cras...
# 5264  The cargo plane crashed while on approach to I...
# 5265  The Airbus went missing over the AtlantiOcean ...
# 5266  The air ambulance crashed into hills while att...
# 5267  The military transport went missing while en r...
#
# [4865 rows x 1 columns]

# %% [markdown]
# ## VECTORISE THE DATA FOR CLUSTRING

# %% [markdown]
# __KMeans normally works with numbers only: we need to have numbers.To get numbers, we do feature extraction.__
#
# __The feature we’ll use is TF-IDF, a numerical statistic. This statistic uses term frequency and inverse document frequency. The method TfidfVectorizer() implements the TF-IDF algorithm.__

# %%
documents = list(Text_data['Summary'])
vectorizer = TfidfVectorizer(stop_words='english') # Stop words are like "a", "the", or "in" which don't have significant meaning
X = vectorizer.fit_transform(documents)

# %%
D = pd.DataFrame(X)
D.iloc[:1]
# Out:
#                                                    0
# 0    (0, 4860)\t0.09553523189963811\n  (0, 8382)\...

# %% [markdown]
# ## MODEL BUILDING

# %%
model = MiniBatchKMeans(n_clusters=5, random_state=0)
model.fit(X)
# Out:
# MiniBatchKMeans(n_clusters=5, random_state=0)

# %%
model.cluster_centers_
# Out:
# array([[0.00000000e+00, 2.96820603e-03, 0.00000000e+00, ...,
#         1.92575673e-03, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.60610587e-03, 0.00000000e+00, ...,
#         0.00000000e+00, 4.66349996e-04, 0.00000000e+00],
#        [6.30188212e-04, 1.00712492e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.56766384e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [6.61127959e-05, 7.23822368e-03, 0.00000000e+00, ...,
#         0.00000000e+00, 4.09611866e-04, 1.19484358e-04]])

# %%
y_pred =  model.predict(X)
y_pred
# Out:
# array([4, 4, 4, ..., 4, 4, 2])

# %%
model.labels_
# Out:
# array([4, 4, 4, ..., 4, 4, 2])

# %% [markdown]
# ## FORMING CLUSTER

# %% [markdown]
# <img align="top"  width="900" height="300" src="https://i1.wp.com/georgepavlides.info/wp-content/uploads/2018/02/kmeans-featured.png?fit=1015%2C882">

# %%
print ('Most Common Terms per Cluster:')

order_centroids = model.cluster_centers_.argsort()[:,::-1] #sort cluster centers by proximity to centroid
terms = vectorizer.get_feature_names()

for i in range(5):
    print("\n")
    print('Cluster %d:' % i)
    for j in order_centroids[i, :10]: #replace 10 with n words per cluster
        print ('%s' % terms[j]),
    print
# Out:
# Most Common Terms per Cluster:
#
#
# Cluster 0:
# engine
# takeoff
# shortly
# crashed
# taking
# failure
# aircraft
# plane
# failed
# lost
#
#
# Cluster 1:
# plane
# cargo
# crashed
# engine
# lost
# runway
# landing
# fuel
# left
# takeoff
#
#
# Cluster 2:
# route
# en
# weather
# conditions
# flight
# crashed
# vfr
# pilot
# adverse
# shot
#
#
# Cluster 3:
# mountain
# struck
# crashed
# flew
# en
# route
# poor
# weather
# cargo
# plane
#
#
# Cluster 4:
# crashed
# aircraft
# approach
# runway
# landing
# land
# pilot
# attempting
# crew
# airport

# %% [markdown]
# ## PREDICTION FOR NEW DATA

# %%
print("\n")
print("Prediction")

Y = vectorizer.transform(["engine failure"])
prediction = model.predict(Y)
print(prediction)

Y = vectorizer.transform(["terrorism"])
prediction = model.predict(Y)
print(prediction)
 

Y = vectorizer.transform([" wing damage"])
prediction = model.predict(Y)
print(prediction)

Y = vectorizer.transform(["India"])
prediction = model.predict(Y)
print(prediction)
# Out:
# Prediction
# [0]
# [4]
# [4]
# [4]

# %% [markdown]
# <img align="top"  width="900" height="300" src="https://images.squarespace-cdn.com/content/v1/5acbdd3a25bf024c12f4c8b4/1608407348392-22767PJ7RQ85BD5RLSLZ/k-means-clustering.png?format=1000w">

# %% [markdown]
# # CONCLUSSION -
# __WE HAVE CLUSTER THE WHOLE DATA IN 5 CLUSTER, NOW ANY NEW DATA IS PASSING THROUGH MODEL IT WILL DEFINE IN WHICH CLUSTER IT WILL LIES.__

# %% [markdown]
# # THE END !
# ## HAPPY CODING  😎😎
